# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://drive.google.com/uc?id=1JY8l5nSu9O4GtMDpaOfH2Oowlpza3U-c')

# %%
data.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
print("Users:",len(data))
# Out:
# Users: 537577

# %%
data.shape
# Out:
# (537577, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
data.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
pd.unique(data["Age"]) # age categories
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
len(data['Age'].unique())
# Out:
# 7

# %%
data.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      17959
# dtype: int64

# %%
out = data.loc[(data["Gender"] == "M") & (data["City_Category"] == "A")] # sort by Gander and City_Category
out.head()
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 5   1000003  P00193542      M  26-35          15             A
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 5                           3               0                   1
# 9                           1               1                   8
# 10                          1               1                   5
# 11                          1               1                   8
# 12                          1               1                   8
#
#     Product_Category_2  Product_Category_3  Purchase
# 5                  2.0                 NaN     15227
# 9                  NaN                 NaN      7871
# ...

# %%
out.shape
# Out:
# (109831, 12)

# %%
data["Product_Category_3"].isnull().sum() # counts NaN
# Out:
# 373299

# %%
women = data.loc[(data["Age"] == "46-50") & (data["Gender"] == "F") & (data["Purchase"] >2000)] # sort by Gander and City_Category
women.head()
# Out:
#      User_ID Product_ID Gender    Age  Occupation City_Category  \
# 248  1000045  P00066442      F  46-50          16             A
# 250  1000045  P00210142      F  46-50          16             A
# 251  1000045  P00212542      F  46-50          16             A
# 252  1000045  P00321742      F  46-50          16             A
# 253  1000045  P00020042      F  46-50          16             A
#
#     Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 248                          1               1                   5
# 250                          1               1                  14
# 251                          1               1                   8
# 252                          1               1                   5
# 253                          1               1                   5
#
#      Product_Category_2  Product_Category_3  Purchase
# 248                14.0                 NaN      6950
# 250                 NaN                 NaN      4325
# ...

# %%
women.shape
# Out:
# (12223, 12)

# %%
women.User_ID.unique()
# Out:
# array([1000045, 1000072, 1000078, 1000079, 1000088, 1000127, 1000137,
#        1000156, 1000159, 1000183, 1000187, 1000193, 1000233, 1000411,
#        1000421, 1000434, 1000447, 1000511, 1000576, 1000656, 1000856,
#        1000905, 1000918, 1000943, 1001026, 1001028, 1001078, 1001103,
#        1001140, 1001233, 1001271, 1001355, 1001364, 1001375, 1001376,
#        1001378, 1001428, 1001455, 1001461, 1001576, 1001654, 1001657,
#        1001766, 1001871, 1001877, 1001899, 1001918, 1002033, 1002034,
#        1002038, 1002044, 1002112, 1002222, 1002230, 1002256, 1002264,
#        1002308, 1002309, 1002355, 1002366, 1002372, 1002408, 1002423,
#        1002441, 1002444, 1002492, 1002512, 1002516, 1002519, 1002540,
#        1002560, 1002580, 1002617, 1002724, 1003093, 1003096, 1003304,
#        1003390, 1003430, 1003431, 1003483, 1003529, 1003589, 1003656,
#        1003779, 1003858, 1003873, 1003945, 1003948, 1003952, 1003981,
# ...
